# %% [markdown]
# # 2. Amplitude modulation

# %%
# %run pykat_notebook_defaults.py
pykat.init_pykat_plotting(dpi=90)
# Out:
# Imported matplotlib.pyplot as plt
# Imported numpy as np
# <style>
# div.html_cell_render{
# }
#
# .rendered_html pre,
# .rendered_html code {
# }
#
# div.text_cell_render {
# font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
# /*font-family: "Charis SIL", serif;  Make non-code text serif. */
# line-height: 145%; /* added for some line spacing of text. */
# width: 105ex; /* instead of 'inherit' for shorter lines */
# font-size: 12pt;
# }
#
# div.text_cell_render h1,
# div.text_cell_render h2,
# div.text_cell_render h3,
# div.text_cell_render h4,
# div.text_cell_render h5,
# div.text_cell_render h6 {
# /*    font-family: 'Kameron';*/
#     font-weight: 300;
# }
#
# div.text_cell_render h1 {
#     font-size: 24pt;
# }
#
# div.text_cell_render h2 {
#     font-size: 18pt;
# }
#
# div.text_cell_render h3 {
#     font-size: 14pt;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     font-size: medium;
# }
#
# .rendered_html ol {
#     list-style:decimal;
# ...

# %% [markdown]
# An amplitude modulated laser field has a time dependent amplitude, thus, it can be described by $E(t) = \big(1+$ <span style="color:Red">$m\cos(\Omega t)$</span>$\big)\cos(\omega t)$. The figure below shows how an amplitude modulated signal may look like. The plot is generated by using $\omega = 80\pi$ rad/s, $\Omega = 4\pi$ rad/s, and $m=0.9$.

# %%
# %run amp_mod_figs.py
